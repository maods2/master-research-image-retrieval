# %%
from utils import (
    plot_permutation_test_distribution,
    permutation_test,
    load_json_file,

)

# %%
# glomerulo
# UNI FSL x DINO pretr
pretreined_model = load_json_file('./permutation_test_models/glomerulo-dino-backbone-map_at_k_query_details.json')
finetuned_model = load_json_file('./permutation_test_models/glomerulo-uni-fsl-map_at_k_query_details.json')

result = permutation_test(finetuned_model, pretreined_model, 95)
plot_permutation_test_distribution(
    result,
    model='UNI x DINO', 
    save_as='perm_test_glomerulo'
    )

# %%
# Ovarian Cancer
# UNI2-h FSL x UNI2-h pretr
pretreined_model = load_json_file('./permutation_test_models/ovarian-cancer-UNI2-h-backbone-map_at_k_query_details.json')
finetuned_model = load_json_file('./permutation_test_models/ovarian-cancer-UNI2-h-fsl-map_at_k_query_details.json')

result = permutation_test(finetuned_model, pretreined_model, 95)
plot_permutation_test_distribution(
    result,
    model='UNI2-h x UNI2-h', 
    save_as='perm_test_ovarian_cancer'
    )

# %%
# Skin Cancer
# Phikon-v2 FSL x DINO pretr
pretreined_model = load_json_file('./permutation_test_models/skin-cancer-dino-backbone-map_at_k_query_details.json')
finetuned_model = load_json_file('./permutation_test_models/skin-cancer-phikon-v2-fsl-map_at_k_query_details.json')

result = permutation_test(finetuned_model, pretreined_model, 95)
plot_permutation_test_distribution(
    result,
    model='Phikon-v2 x DINO', 
    save_as='perm_test_skin_cancer'
    )
