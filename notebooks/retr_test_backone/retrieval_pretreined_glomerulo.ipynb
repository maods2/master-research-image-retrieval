# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

from utils import (
    get_latest_experiments,
    aggregate_metrics,
    plot_all_metrics,
    plot_class_performances,
    plot_metric_comparison,
    permutation_test,
    plot_permutation_test_distribution,
    plot_permutation_anova_distribution,
    permutation_anova, 
    calculate_class_performance,
    plot_class_performance,
    plot_class_performance_comparison,
    plot_classes_maps,
    METRIC_FILES
)

BASE_DIR = "../../local_experiments/retr_test_backone_glomerulo"

# %%
# Specify a list of experiment folder names.
# Example usage:
#   - specific_experiments = []             -> process the latest experiment for each type.
#   - specific_experiments = ["exp1_folder"]  -> process only that experiment.
#   - specific_experiments = ["exp1_folder", "exp2_folder"] -> process multiple experiments.
specific_experiments = []  # Change as needed; empty list means "use latest per experiment type"

# Retrieve the experiments based on the provided filter.
latest_experiments = get_latest_experiments(BASE_DIR, specific_experiments)

# %%
latest_experiments
# Out:
# {'dinov2_glomerulo': {'folder': 'dinov2_glomerulo_2025-05-25_22-11-43',
#   'timestamp': datetime.datetime(2025, 5, 25, 22, 11, 43),
#   'path': '../../local_experiments/retr_test_backone_glomerulo/dinov2_glomerulo_2025-05-25_22-11-43'},
#  'dino_glomerulo': {'folder': 'dino_glomerulo_2025-05-25_22-09-26',
#   'timestamp': datetime.datetime(2025, 5, 25, 22, 9, 26),
#   'path': '../../local_experiments/retr_test_backone_glomerulo/dino_glomerulo_2025-05-25_22-09-26'},
#  'phikon2_glomerulo': {'folder': 'phikon2_glomerulo_2025-05-26_15-30-28',
#   'timestamp': datetime.datetime(2025, 5, 26, 15, 30, 28),
#   'path': '../../local_experiments/retr_test_backone_glomerulo/phikon2_glomerulo_2025-05-26_15-30-28'},
#  'phikon_glomerulo': {'folder': 'phikon_glomerulo_2025-05-26_15-22-42',
#   'timestamp': datetime.datetime(2025, 5, 26, 15, 22, 42),
#   'path': '../../local_experiments/retr_test_backone_glomerulo/phikon_glomerulo_2025-05-26_15-22-42'},
#  'philkon2_glomerulo': {'folder': 'philkon2_glomerulo_2025-05-26_04-45-20',
#   'timestamp': datetime.datetime(2025, 5, 26, 4, 45, 20),
#   'path': '../../local_experiments/retr_test_backone_glomerulo/philkon2_glomerulo_2025-05-26_04-45-20'},
#  'philkon_glomerulo': {'folder': 'philkon_glomerulo_2025-05-26_04-45-12',
#   'timestamp': datetime.datetime(2025, 5, 26, 4, 45, 12),
#   'path': '../../local_experiments/retr_test_backone_glomerulo/philkon_glomerulo_2025-05-26_04-45-12'},
#  'resnet_glomerulo': {'folder': 'resnet_glomerulo_2025-05-25_22-01-01',
#   'timestamp': datetime.datetime(2025, 5, 25, 22, 1, 1),
#   'path': '../../local_experiments/retr_test_backone_glomerulo/resnet_glomerulo_2025-05-25_22-01-01'},
#  'UNI2-h_glomerulo': {'folder': 'UNI2-h_glomerulo_2025-05-26_03-30-23',
#   'timestamp': datetime.datetime(2025, 5, 26, 3, 30, 23),
#   'path': '../../local_experiments/retr_test_backone_glomerulo/UNI2-h_glomerulo_2025-05-26_03-30-23'},
#  'uni_glomerulo': {'folder': 'uni_glomerulo_2025-05-25_22-35-19',
#   'timestamp': datetime.datetime(2025, 5, 25, 22, 35, 19),
#   'path': '../../local_experiments/retr_test_backone_glomerulo/uni_glomerulo_2025-05-25_22-35-19'},
#  'virchow2_glomerulo': {'folder': 'virchow2_glomerulo_2025-05-26_15-30-35',
#   'timestamp': datetime.datetime(2025, 5, 26, 15, 30, 35),
#   'path': '../../local_experiments/retr_test_backone_glomerulo/virchow2_glomerulo_2025-05-26_15-30-35'},
#  'vit_glomerulo': {'folder': 'vit_glomerulo_2025-05-25_22-02-43',
#   'timestamp': datetime.datetime(2025, 5, 25, 22, 2, 43),
#   'path': '../../local_experiments/retr_test_backone_glomerulo/vit_glomerulo_2025-05-25_22-02-43'}}

# %%
plot_metric_comparison("mAP", latest_experiments)
# Aumentar a letra "K"
# Top 10
# Applicar normalização nos embeddings
# usar apenas datasewt Glomerlo, Ovarian cance e skin cancer
# Out:
# File not found: ../../local_experiments/retr_test_backone_glomerulo/phikon2_glomerulo_2025-05-26_15-30-28/map_at_k_results.json
# Warning: No data for mAP in experiment phikon2_glomerulo_2025-05-26_15-30-28
# File not found: ../../local_experiments/retr_test_backone_glomerulo/philkon2_glomerulo_2025-05-26_04-45-20/map_at_k_results.json
# Warning: No data for mAP in experiment philkon2_glomerulo_2025-05-26_04-45-20
# File not found: ../../local_experiments/retr_test_backone_glomerulo/philkon_glomerulo_2025-05-26_04-45-12/map_at_k_results.json
# Warning: No data for mAP in experiment philkon_glomerulo_2025-05-26_04-45-12

# %%
exp1 = '../local_experiments/glomerulo/uni_fsl_glomerulo_2025-04-20_15-11-18/map_at_k_query_details.json'
exp2 = '../local_experiments/glomerulo/uni_glomerulo_2025-04-16_04-08-18/map_at_k_query_details.json'
performance = calculate_class_performance(exp1)
# plot_class_performance(performance, 'map')

# performance = calculate_class_performance()
# plot_class_performance(performance, 'map')

plot_class_performance_comparison(exp1, exp2, label1="Uni Few Shot Learning", label2="Uni Vit Embeddings", title="Map@k Performance Comparison per class")
# Out:
# File not found: ../local_experiments/glomerulo/uni_fsl_glomerulo_2025-04-20_15-11-18/map_at_k_query_details.json
# File not found: ../local_experiments/glomerulo/uni_fsl_glomerulo_2025-04-20_15-11-18/map_at_k_query_details.json
# File not found: ../local_experiments/glomerulo/uni_glomerulo_2025-04-16_04-08-18/map_at_k_query_details.json
# Insufficient data to plot comparison.

# %%
performance
# Out:
# {}

# %%
res1 = calculate_class_performance(exp1)
res2 = calculate_class_performance(exp2)
for (cls, res), (cls2, res2 ) in zip(res1.items(), res2.items()):
    # print(i)
    print(f'FSL UNI total={res["total"]}, correct={res["correct"]}, erro={res["errors"]} {cls}')
    print(f'    UNI total={res2["total"]}, correct={res2["correct"]}, erro={res2["errors"]} {cls2}')
    print()
# Out:
# File not found: ../local_experiments/glomerulo/uni_fsl_glomerulo_2025-04-20_15-11-18/map_at_k_query_details.json
# File not found: ../local_experiments/glomerulo/uni_glomerulo_2025-04-16_04-08-18/map_at_k_query_details.json

# %%
plot_classes_maps(latest_experiments)
# Out:
# Plotting class map for dinov2_glomerulo with k=15...
# /workspaces/master-research-image-retrieval/notebooks/utils.py:395: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(classes, rotation=45, ha='right')
# Plotting class map for dino_glomerulo with k=15...
# /workspaces/master-research-image-retrieval/notebooks/utils.py:395: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(classes, rotation=45, ha='right')
# File not found: ../../local_experiments/retr_test_backone_glomerulo/phikon2_glomerulo_2025-05-26_15-30-28/map_at_k_query_details.json
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plot_classes_maps(latest_experiments)
#
# File /workspaces/master-research-image-retrieval/notebooks/utils.py:423, in plot_classes_maps(latest_experiments, metric_suffix)
#     421 path = files["path"]
#     422 file = path + "/" + metric_suffix
# --> 423 class_map, k = calculate_class_map(file)
#     424 print(f"Plotting class map for {model} with k={k}...")
#     425 plot_class_map(class_map, title=f"{model} - Average Precision per Class", k=k)
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
plot_class_performances(latest_experiments)
# Out:
# File not found: ../../local_experiments/retr_test_backone_glomerulo/phikon2_glomerulo_2025-05-26_15-30-28/map_at_k_query_details.json
# No class statistics to plot.
# File not found: ../../local_experiments/retr_test_backone_glomerulo/philkon2_glomerulo_2025-05-26_04-45-20/map_at_k_query_details.json
# No class statistics to plot.
# File not found: ../../local_experiments/retr_test_backone_glomerulo/philkon_glomerulo_2025-05-26_04-45-12/map_at_k_query_details.json
# No class statistics to plot.

# %%
# Load map_at_k_query_details.json for each model in latest_experiments
models = {}
for model_name, model_info in latest_experiments.items():
    details_file = f"{model_info['path']}/{METRIC_FILES['map']['details']}"
    try:
        with open(details_file, "r") as f:
            models[model_name] = json.load(f)
    except:
        pass
# Dynamically assign models to variables for hypothesis testing
locals().update({f"model{i+1}": models[model_name] for i, model_name in enumerate(models.keys())})

# %%
result = permutation_test(model1, model2, 95)
plot_permutation_test_distribution(result)

# %%
result = permutation_test(model1, model3, 95)
plot_permutation_test_distribution(result)

# %%
res = permutation_anova([model1, model2, model3, model4], n_permutations=10000, seed=42, confidence=95)
plot_permutation_anova_distribution(res)
