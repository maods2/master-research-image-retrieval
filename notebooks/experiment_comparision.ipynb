# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


def plot_images_side_by_side(img_path1, img_path2, global_title, img1_title, img2_title):
    img1 = mpimg.imread(img_path1)
    img2 = mpimg.imread(img_path2)
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    fig.suptitle(global_title)
    axes[0].imshow(img1)
    axes[0].set_title(img1_title)
    axes[0].axis('off')
    axes[1].imshow(img2)
    axes[1].set_title(img2_title)
    axes[1].axis('off')
    plt.show()

# %%
plot_images_side_by_side(
    img_path1='./no_fine_tuning/bracs-pretrained.png', 
    img_path2='./fsl/glomerulo-fsl.png', 
    global_title='Glomerulo', 
    img1_title='Backbone', 
    img2_title='FSL'
    )

# %%
plot_images_side_by_side(
    img_path1='./no_fine_tuning/bracs-pretrained.png', 
    img_path2='./fsl/bracs-fsl.png', 
    global_title='Lesões Mamárias - bracs', 
    img1_title='Backbone', 
    img2_title='FSL'
    )

# %%
plot_images_side_by_side(
    img_path1='./no_fine_tuning/CRC-VAL-HE-7K-pretrained.png', 
    img_path2='./fsl/CRC-VAL-HE-7K-fsl.png', 
    global_title='Cancer de Cólon', 
    img1_title='Backbone', 
    img2_title='FSL'
    )

# %%
plot_images_side_by_side(
    img_path1='./no_fine_tuning/ovarian-cancer-pretrained.png', 
    img_path2='./fsl/ovarian-cancer-fsl.png', 
    global_title='Cancer de Ovário', 
    img1_title='Backbone', 
    img2_title='FSL'
    )

# %%
plot_images_side_by_side(
    img_path1='./no_fine_tuning/skin-cancer-pretrained.png', 
    img_path2='./fsl/skin-cancer-fsl.png', 
    global_title='Cancer de Pele', 
    img1_title='Backbone', 
    img2_title='FSL'
    )
